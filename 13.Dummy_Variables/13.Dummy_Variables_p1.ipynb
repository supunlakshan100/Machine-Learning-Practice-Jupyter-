# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/AI & Machine Learning/Machine Learning/ML Practice/13.Dummy_Variables/GPA_data.CSV")

# %%
data.head(10)
# Out:
#      ID  Gender  Age Extra_Curricular  Study_Hours  Annual_Income  \
# 0  8867    Male   22        Societies           10        1318792
# 1  1316  Female   24        Societies            9         874657
# 2  9443    Male   22        Societies           15        1098331
# 3  1829  Female   25               No            9        1680585
# 4  1989    Male   26               No            7        1361560
# 5  7297  Female   25        Societies            5         887824
# 6  7447    Male   23        Societies           10        1957325
# 7  2018    Male   21        Societies            7        1602856
# 8  1136  Female   23        Societies            8         429437
# 9  7702    Male   26           Sports            6         536744
#
#    Distance_From_Home   GPA
# 0                 154  1.76
# 1                 181  3.88
# 2                  94  1.73
# 3                   8  1.29
# 4                 122  3.19
# 5                 107  2.42
# 6                  22  3.05
# ...

# %%
data["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data["Extra_Curricular"].unique()
# Out:
# array(['Societies', 'No', 'Sports'], dtype=object)

# %%
data[["Gender","Extra_Curricular"]]
# Out:
#      Gender Extra_Curricular
# 0      Male        Societies
# 1    Female        Societies
# 2      Male        Societies
# 3    Female               No
# 4      Male               No
# ..      ...              ...
# 995  Female               No
# 996    Male               No
# 997    Male           Sports
# 998    Male        Societies
# 999    Male               No
#
# [1000 rows x 2 columns]

# %%
df_dummy=pd.get_dummies(data[["Gender","Extra_Curricular"]])

# %%
df_dummy.head()
# Out:
#    Gender_Female  Gender_Male  Extra_Curricular_No  \
# 0              0            1                    0
# 1              1            0                    0
# 2              0            1                    0
# 3              1            0                    1
# 4              0            1                    1
#
#    Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                           1                        0
# 1                           1                        0
# 2                           1                        0
# 3                           0                        0
# 4                           0                        0

# %%
df_dummy.drop(["Gender_Female","Extra_Curricular_No"],axis=1,inplace=True)

# %%
df_dummy.head()
# Out:
#    Gender_Male  Extra_Curricular_Societies  Extra_Curricular_Sports
# 0            1                           1                        0
# 1            0                           1                        0
# 2            1                           1                        0
# 3            0                           0                        0
# 4            1                           0                        0

# %%
df_new=pd.concat([data,df_dummy],axis=1)

# %%
df_new.head()
# Out:
#      ID  Gender  Age Extra_Curricular  Study_Hours  Annual_Income  \
# 0  8867    Male   22        Societies           10        1318792
# 1  1316  Female   24        Societies            9         874657
# 2  9443    Male   22        Societies           15        1098331
# 3  1829  Female   25               No            9        1680585
# 4  1989    Male   26               No            7        1361560
#
#    Distance_From_Home   GPA  Gender_Male  Extra_Curricular_Societies  \
# 0                 154  1.76            1                           1
# 1                 181  3.88            0                           1
# 2                  94  1.73            1                           1
# 3                   8  1.29            0                           0
# 4                 122  3.19            1                           0
#
#    Extra_Curricular_Sports
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# ...

# %%
df_new.drop(["Gender","Extra_Curricular"],axis=1,inplace=True)

# %%
df_new.head()
# Out:
#      ID  Age  Study_Hours  Annual_Income  Distance_From_Home   GPA  \
# 0  8867   22           10        1318792                 154  1.76
# 1  1316   24            9         874657                 181  3.88
# 2  9443   22           15        1098331                  94  1.73
# 3  1829   25            9        1680585                   8  1.29
# 4  1989   26            7        1361560                 122  3.19
#
#    Gender_Male  Extra_Curricular_Societies  Extra_Curricular_Sports
# 0            1                           1                        0
# 1            0                           1                        0
# 2            1                           1                        0
# 3            0                           0                        0
# 4            1                           0                        0

# %%
list(df_new.columns)
# Out:
# ['ID',
#  'Age',
#  'Study_Hours',
#  'Annual_Income',
#  'Distance_From_Home',
#  'GPA',
#  'Gender_Male',
#  'Extra_Curricular_Societies',
#  'Extra_Curricular_Sports']

# %%
col = list(df_new.columns)  # Assuming df_new is your DataFrame

# Reindexing the DataFrame with column modifications
df_new=df_new.reindex(columns=col[:5] + col[6:] + ["GPA"])

# %%
df_new.drop("ID",axis=1,inplace=True)

# %%
df_new.head()
# Out:
#    Age  Study_Hours  Annual_Income  Distance_From_Home  Gender_Male  \
# 0   22           10        1318792                 154            1
# 1   24            9         874657                 181            0
# 2   22           15        1098331                  94            1
# 3   25            9        1680585                   8            0
# 4   26            7        1361560                 122            1
#
#    Extra_Curricular_Societies  Extra_Curricular_Sports   GPA
# 0                           1                        0  1.76
# 1                           1                        0  3.88
# 2                           1                        0  1.73
# 3                           0                        0  1.29
# 4                           0                        0  3.19

# %%
x=df_new.iloc[:,:7]

# %%
x
# Out:
#      Age  Study_Hours  Annual_Income  Distance_From_Home  Gender_Male  \
# 0     22           10        1318792                 154            1
# 1     24            9         874657                 181            0
# 2     22           15        1098331                  94            1
# 3     25            9        1680585                   8            0
# 4     26            7        1361560                 122            1
# ..   ...          ...            ...                 ...          ...
# 995   22            5        1675219                  27            0
# 996   24            8         947439                 125            1
# 997   26            6        1912975                  67            1
# 998   22           12         341543                  86            1
# 999   23           12         975142                  87            1
#
#      Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                             1                        0
# ...
